# %% [markdown]
# <a href="https://www.kaggle.com/code/maowmaowtess/global-hack-week-teresa?scriptVersionId=158489379" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Hello, World!

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# # Sorting Method

# %%
Fruit=["Apple","Bannana","Strawberry","Peach","Mango"]
Fruit.sort()
Fruit
# Out:
# ['Apple', 'Bannana', 'Mango', 'Peach', 'Strawberry']

# %% [markdown]
# # Rock Paper Scissor Game

# %%
import random

while True:
    user_action = input("Enter a choice (rock, paper, scissors)")
    possible_actions = ["rock", "paper", "scissors"]
    computer_action = random.choice(possible_actions)
    print(f"\nYou chose {user_action}, computer chose {computer_action}.\n")

    if user_action == computer_action:
        print(f"Both players selected {user_action}. It's a tie!")
    elif user_action == "rock":
        if computer_action == "scissors":
            print("Rock smashes scissors! You win!")
        else:
            print("Paper covers rock! You lose.")
    elif user_action == "paper":
        if computer_action == "rock":
            print("Paper covers rock! You win!")
        else:
            print("Scissors cuts paper! You lose.")
    elif user_action == "scissors":
        if computer_action == "paper":
            print("Scissors cuts paper! You win!")
        else:
            print("Rock smashes scissors! You lose.")

    play_again = input("Play again? (y/n): ")
    if play_again.lower() != "y":
        break

# %% [markdown]
# # Random Number Generator

# %%
import random 

number=random.random()
print(number)

# %% [markdown]
# # A Project To Achieve My New Years Resolution

# %%
#I want to be less sad/angry this year so I made a way to track my day by day emotions.

# %%
import json
from datetime import datetime

def log_mood():
    mood = input("How are you feeling today? :)")
    date = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

    entry = {"date": date, "mood": mood}

    with open("mood_log.json", "a") as file:
        json.dump(entry, file)
        file.write("\n")

def view_mood_log():
    try:
        with open("mood_log.json", "r") as file:
            entries = [json.loads(line) for line in file]
            for entry in entries:
                print(f"{entry['date']} - {entry['mood']}")
    except FileNotFoundError:
        print("No mood entries found.")

while True:
    print("\n1. Log Mood\n2. View Mood Log\n3. Exit")
    choice = input("Enter your choice (1/2/3): ")

    if choice == "1":
        log_mood()
    elif choice == "2":
        view_mood_log()
    elif choice == "3":
        print("Okay Bye Bye. Have a lovely day!")
        break
    else:
        print("Invalid choice. Please enter 1, 2, or 3.")

# %% [markdown]
# # Useless Code

# %%
def ask_if_human():
    response = input("Are you human? (yes/no): ").lower()

    while response == "yes":
        response = input("Are you sure? (yes/no): ").lower()

    print("Verification failed. Please try again later.")

ask_if_human()
